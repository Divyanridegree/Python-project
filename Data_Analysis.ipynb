# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanridegree/Python-project/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'Weight' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  Weight  friends  cousins  projects
# 0       52      64       14        8        78
# 1       93      57       12       10        44
# 2       51      59       19        7        31
# 3       29      58       11        6        44
# 4       22      67       15        9        77
# ..     ...     ...      ...      ...       ...
# 995     40      61       12        5        21
# 996     87      62       18        8        48
# 997     14      64       11        9        75
# 998     75      70       15        5        31
# 999     55      58       16        6        47
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       Weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.169000    60.216000    15.121000     7.444000    50.549000
# std      29.674552     6.043167     3.189754     1.719832    17.705793
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      24.000000    55.000000    12.000000     6.000000    35.000000
# 50%      52.000000    61.000000    15.000000     7.000000    51.000000
# 75%      76.000000    66.000000    18.000000     9.000000    66.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friends18 = df1['friends']>18

# %%
df1[friends18]
# Out:
#      grade  Weight  friends  cousins  projects
# 2       51      59       19        7        31
# 20      62      57       20       10        61
# 24      16      69       19        7        72
# 26      22      65       19        8        46
# 31      70      67       20        5        37
# ..     ...     ...      ...      ...       ...
# 984     69      69       19        6        38
# 985     50      62       19        8        20
# 986     35      53       19        8        36
# 993     52      63       20       10        53
# 994     20      59       20        8        48
#
# [192 rows x 5 columns]

# %%
df1[friends18].describe()
# Out:
#             grade      Weight     friends     cousins    projects
# count  192.000000  192.000000  192.000000  192.000000  192.000000
# mean    48.734375   60.109375   19.546875    7.348958   49.296875
# std     30.108656    6.073159    0.499099    1.714765   18.169372
# min      0.000000   50.000000   19.000000    5.000000   20.000000
# 25%     23.000000   55.000000   19.000000    6.000000   32.000000
# 50%     48.500000   61.000000   20.000000    8.000000   48.000000
# 75%     74.000000   65.250000   20.000000    9.000000   66.250000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
grade50 = df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  Weight  friends  cousins  projects
# 0       52      64       14        8        78
# 1       93      57       12       10        44
# 2       51      59       19        7        31
# 5       67      57       16        5        30
# 6       71      53       12        5        78
# ..     ...     ...      ...      ...       ...
# 991     73      65       14        9        34
# 993     52      63       20       10        53
# 996     87      62       18        8        48
# 998     75      70       15        5        31
# 999     55      58       16        6        47
#
# [512 rows x 5 columns]

# %%
df1[friends18 & grade50] ['friends']
# Out:
# 2      19
# 20     20
# 31     20
# 35     20
# 40     20
#        ..
# 966    19
# 970    20
# 975    20
# 984    19
# 993    20
# Name: friends, Length: 94, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friends18 & grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friends18 & grade50].plot()
# Out:
# <Axes: >

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friends18 & grade50].plot(x='grade',y='projects',kind='scatter')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend('Test Data')
plt.show()

# %%
fdf = df1[friends18 & grade50]

# %%
df1
# Out:
#      grade  Weight  friends  cousins  projects
# 0       52      64       14        8        78
# 1       93      57       12       10        44
# 2       51      59       19        7        31
# 3       29      58       11        6        44
# 4       22      67       15        9        77
# ..     ...     ...      ...      ...       ...
# 995     40      61       12        5        21
# 996     87      62       18        8        48
# 997     14      64       11        9        75
# 998     75      70       15        5        31
# 999     55      58       16        6        47
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('/Divya.csv')
