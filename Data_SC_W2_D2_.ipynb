# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanridegree/Python-project/blob/main/Data_SC_W2_D2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
datasetPath = '/content/matches_1930_2022.csv'

# %%
df = pd.read_csv(datasetPath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoredAboveZero = df['Score'] > '0-0'

# %%
df[ScoredAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
ScoredByBrazil = df['home_team']=='Brazil'

# %%
df[ScoredAboveZero & ScoredByBrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf = df[ScoredAboveZero & ScoredByBrazil].sort_values (by='home_team',ascending=True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 796    Brazil  Czechoslovakia           3      NaN           NaN           1
# 792    Brazil        Bulgaria           2      NaN           NaN           0
# 757    Brazil  Czechoslovakia           4      NaN           NaN           1
# 749    Brazil         England           1      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 384    Brazil          France           0      NaN           NaN           3
# 374    Brazil         Türkiye           2      NaN           NaN           1
# 360    Brazil        China PR           4      NaN           NaN           0
# 628    Brazil     New Zealand           4      NaN           NaN           0
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager           home_captain  ...  \
# 11       0.5           NaN                 Tite           Thiago Silva  ...
# 796      NaN           NaN       Aymore Moreira            Mauro Ramos  ...
# 792      NaN           NaN        Vicente Feola     Hilderaldo Bellini  ...
# 757      NaN           NaN        Mario Zagallo  Carlos Alberto Torres  ...
# 749      NaN           NaN        Mario Zagallo  Carlos Alberto Torres  ...
# ..       ...           ...                  ...                    ...  ...
# 384      NaN           NaN        Mário Zagallo                    NaN  ...
# 374      NaN           NaN  Luiz Felipe Scolari                    NaN  ...
# 360      NaN           NaN  Luiz Felipe Scolari                    NaN  ...
# 628      NaN           NaN         Tele Santana               Sócrates  ...
# 951      NaN           NaN  Pindaro De Carvalho              Preguinho  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11                              NaN                             NaN
# 796                             NaN                             NaN
# 792                             NaN                             NaN
# 757                             NaN                             NaN
# 749                             NaN                             NaN
# ..                              ...                             ...
# 384                             NaN                             NaN
# 374                             NaN                             NaN
# 360                             NaN                             NaN
# 628                             NaN                             NaN
# 951                             NaN                             NaN
#
#      home_red_card away_red_card home_yellow_red_card  \
# 11             NaN           NaN                  NaN
# 796            NaN           NaN                  NaN
# 792            NaN           NaN                  NaN
# 757            NaN           NaN                  NaN
# 749            NaN           NaN                  NaN
# ..             ...           ...                  ...
# 384            NaN           NaN                  NaN
# 374            NaN           NaN                  NaN
# 360            NaN           NaN                  NaN
# 628            NaN           NaN                  NaN
# 951            NaN           NaN                  NaN
#
#                      away_yellow_red_card  \
# 11                                    NaN
# 796                                   NaN
# 792                                   NaN
# 757                                   NaN
# 749                                   NaN
# ..                                    ...
# 384                  Marcel Desailly · 68
# 374  Alpay Özalan · 86|Hakan Ünsal · 90+4
# 360                                   NaN
# 628                                   NaN
# 951                                   NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 796                                                NaN
# 792        ['1&rsquor;|0:0|Denílson Custódio Machado']
# 757   ['1&rsquor;|0:0|Gérson', '1&rsquor;|0:0|Tostão']
# 749                                                NaN
# ..                                                 ...
# 384                   ['33&rsquor;|0:1|Júnior Baiano']
# 374                        ['73&rsquor;|1:1|Denílson']
# 360  ['25&rsquor;|1:0|Ronaldinho', '69&rsquor;|4:0|...
# 628                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 796                                                NaN
# 792  ['1&rsquor;|0:0|Dobromir Zhechev', '1&rsquor;|...
# 757                ['1&rsquor;|0:0|Alexander Horváth']
# 749                      ['1&rsquor;|0:0|Francis Lee']
# ..                                                 ...
# 384  ['39&rsquor;|0:1|Didier Deschamps', '48&rsquor...
# 374  ['21&rsquor;|0:0|Fatih Akyel', '24&rsquor;|0:0...
# 360                                                NaN
# 628                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 796                                                NaN
# 792                                                NaN
# 757     ['62&rsquor;|3:1|Paulo Cézar Caju|for Gérson']
# 749      ['68&rsquor;|1:0|Roberto Miranda|for Tostão']
# ..                                                 ...
# 384  ['46&rsquor;|0:2|Denílson Custódio Machado|for...
# 374  ['67&rsquor;|1:1|Denílson|for Ronaldinho', '72...
# 360  ['46&rsquor;|3:0|Denílson|for Ronaldinho', '70...
# 628  ['75&rsquor;|4:0|Paulo Isidoro|for Serginho Ch...
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 796                                                NaN
# 792                                                NaN
# 757  ['46&rsquor;|1:1|Andrej Kvašňák|for Ivan Hrdli...
# 749  ['63&rsquor;|1:0|Colin Bell|for Bobby Charlton...
# ..                                                 ...
# 384  ['57&rsquor;|0:2|Alain Boghossian|for Christia...
# 374  ['66&rsquor;|1:1|İlhan Mansız|for Bülent Korkm...
# 360  ['62&rsquor;|4:0|Yang Pu|for Ma Mingyu', '66&r...
# 628  ['78&rsquor;|4:0|Brian Turner|for Kenny Cressw...
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 11 to 951
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
brazildf.plot(x='home_score',y='away_score',kind='scatter')
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.legend('Take Away')
plt.title('Brazil Matches')
plt.show()

# %%
brazildf.plot(x='Year',y='home_score',kind='hexbin')
plt.xlabel('Year')
plt.ylabel('Home Score')
plt.legend('Take Away')
plt.title('Brazil Matches')
plt.show()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
def AnalyzeFrance():
   matchesPlayed = df['home_team'].value_counts()['France']
   print(f'Total Number of matchePlayed by France is {matchesPlayed}')
AnalyzeFrance()
# Out:
# Total Number of matchePlayed by France is 38

# %%
def AnalyzeTowns():
    TownData = df['home_team'].value_counts()
    for _ in TownData.index:
      print(f'Total Number of matches played by {_} is : {TownData[_]}')

# %%
AnalyzeTowns()
# Out:
# Total Number of matches played by Brazil is : 85
# Total Number of matches played by Argentina is : 59
# Total Number of matches played by Italy is : 57
# Total Number of matches played by England is : 40
# Total Number of matches played by Germany is : 40
# Total Number of matches played by France is : 38
# Total Number of matches played by West Germany is : 38
# Total Number of matches played by Spain is : 34
# Total Number of matches played by Netherlands is : 33
# Total Number of matches played by Uruguay is : 33
# Total Number of matches played by Sweden is : 30
# Total Number of matches played by Belgium is : 23
# Total Number of matches played by Portugal is : 21
# Total Number of matches played by Poland is : 20
# Total Number of matches played by Soviet Union is : 18
# Total Number of matches played by Hungary is : 18
# Total Number of matches played by Mexico is : 18
# Total Number of matches played by Korea Republic is : 18
# Total Number of matches played by Switzerland is : 16
# Total Number of matches played by United States is : 16
# Total Number of matches played by Yugoslavia is : 16
# Total Number of matches played by Japan is : 15
# Total Number of matches played by Chile is : 14
# Total Number of matches played by Cameroon is : 13
# Total Number of matches played by Austria is : 12
# Total Number of matches played by Paraguay is : 11
# Total Number of matches played by Nigeria is : 11
# Total Number of matches played by Denmark is : 10
# Total Number of matches played by Czechoslovakia is : 10
# Total Number of matches played by Croatia is : 10
# Total Number of matches played by Scotland is : 9
# Total Number of matches played by Romania is : 9
# Total Number of matches played by Colombia is : 8
# Total Number of matches played by Morocco is : 8
# Total Number of matches played by Saudi Arabia is : 8
# Total Number of matches played by Australia is : 8
# Total Number of matches played by Costa Rica is : 8
# Total Number of matches played by Tunisia is : 7
# Total Number of matches played by Bulgaria is : 7
# Total Number of matches played by Peru is : 6
# Total Number of matches played by South Africa is : 6
# Total Number of matches played by Russia is : 6
# Total Number of matches played by Algeria is : 6
# Total Number of matches played by Ecuador is : 5
# Total Number of matches played by IR Iran is : 5
# Total Number of matches played by Ghana is : 5
# Total Number of matches played by Republic of Ireland is : 5
# Total Number of matches played by Honduras is : 5
# Total Number of matches played by Northern Ireland is : 5
# Total Number of matches played by Serbia is : 4
# Total Number of matches played by Greece is : 4
# Total Number of matches played by Senegal is : 4
# Total Number of matches played by Korea DPR is : 3
# Total Number of matches played by Germany DR is : 3
# Total Number of matches played by Slovenia is : 3
# Total Number of matches played by Côte d'Ivoire is : 3
# Total Number of matches played by Wales is : 3
# Total Number of matches played by Iraq is : 2
# Total Number of matches played by Zaire is : 2
# Total Number of matches played by Cuba is : 2
# Total Number of matches played by Canada is : 2
# Total Number of matches played by Qatar is : 2
# Total Number of matches played by Slovakia is : 2
# Total Number of matches played by Czech Republic is : 2
# Total Number of matches played by Togo is : 2
# Total Number of matches played by Türkiye is : 2
# Total Number of matches played by China PR is : 1
# Total Number of matches played by United Arab Emirates is : 1
# Total Number of matches played by Haiti is : 1
# Total Number of matches played by Panama is : 1
# Total Number of matches played by Iceland is : 1
# Total Number of matches played by Egypt is : 1
# Total Number of matches played by Ukraine is : 1
# Total Number of matches played by New Zealand is : 1
# Total Number of matches played by Norway is : 1
# Total Number of matches played by Bolivia is : 1
# Total Number of matches played by Serbia and Montenegro is : 1
# Total Number of matches played by Jamaica is : 1
# Total Number of matches played by FR Yugoslavia is : 1
# Total Number of matches played by Angola is : 1
# Total Number of matches played by Trinidad and Tobago is : 1
# Total Number of matches played by Bosnia and Herzegovina is : 1

# %%
# %matplotlib inline

# %%
Town30 = df['home_team'].value_counts().values>30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
townName=[]
matchesPlayed=[]
TownData = df['home_team'].value_counts()
for _ in TownData.index:
    if TownData[_]>30:
     townName.append(_)
     matchesPlayed.append(TownData[_])

# %%
townName
# Out:
# ['Brazil',
#  'Argentina',
#  'Italy',
#  'England',
#  'Germany',
#  'France',
#  'West Germany',
#  'Spain',
#  'Netherlands',
#  'Uruguay']

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(matchesPlayed,townName)
plt.ylabel('Town Name')
plt.xlabel('Matches Played')
plt.title('Matches played by Towns')
plt.show()

# %%
plt.bar(townName,matchesPlayed)
plt.xlabel('TownName')
plt.ylabel('MatchesPlayed')
plt.title('MatchesPlayed by Town')
plt.show()

# %%
plt.barh(townName,matchesPlayed)
plt.xlabel('TownName')
plt.ylabel('MatchesPlayed')
plt.title('MatchesPlayed by Town')
plt.show()

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
teamAbove30=df['home_team'].value_counts()

# %%
teamAbove30
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
Above30 = df['home_team'].value_counts()

# %%
filteredData=Above30[Above30>30]

# %%
filteredData.plot(kind='bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
def MatchesPlayedByTown2():
    Above30 = df['home_team'].value_counts()
    filteredData = Above30[Above30 > 30]
    filteredData.plot(kind='barh')

# %%
MatchesPlayedByTown2()

# %%
def MatchesPlayedByTown():
    townName=[]
    MatchesPlayed=[]
    TownData=df['home_team'].value_counts()
    for _ in TownData.index:
       if TownData[_]>30:
          townName.append(_)
          MatchesPlayed.append(TownData[_])
plt.plot(townName,matchesPlayed)
plt.xlabel('TownName')
plt.ylabel('MatchesPlayed')
plt.title('MatchesPlayed by Town')
plt.show()

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
f2=filteredData[filteredData>=40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy', 'England', 'Germany'], dtype='object', name='home_team')

# %%
df2=df[df["home_team"].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 5      England          France           1      2.4           NaN           2
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 13     England         Senegal           3      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 5        0.9           NaN     Gareth Southgate       Harry Kane  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 13       0.8           NaN     Gareth Southgate       Harry Kane  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 5                               NaN
# 11                              NaN
# 13                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 5                                                  NaN            NaN
# 11                                                 NaN            NaN
# 13                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 5             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 13            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 5                     ['90&rsquor;|1:2|Harry Maguire']
# 11                                                 NaN
# 13                                                 NaN
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 13                ['76&rsquor;|3:0|Kalidou Koulibaly']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 13   ['65&rsquor;|3:0|Jack Grealish|for Phil Foden'...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 13   ['46&rsquor;|2:0|Pape Matar Sarr|for Krépin Di...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [281 rows x 44 columns]

# %%
df2['home_xg'].value_counts()
# Out:
# home_xg
# 2.2    2
# 2.4    2
# 1.0    2
# 1.4    2
# 2.8    2
# 2.1    1
# 1.3    1
# 2.6    1
# 0.9    1
# 2.7    1
# 3.3    1
# 2.3    1
# 3.1    1
# 0.8    1
# 0.3    1
# 1.6    1
# 3.6    1
# 1.9    1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
df2.plot(x='home_team', y='home_xg',kind='bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
f3=df2["home_xg"]>2.5

# %%
df3=df2[f3]

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
from matplotlib import pyplot as plt

# %%
df3.plot(x='home_team',y='home_xg',kind='bar')
plt.xlabel('Home Team')
plt.ylabel('Home Xg')
plt.title('Home Teams Estimated Goals')
plt.show()

# %%
df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
df3.plot(x='home_team',y=['home_score','home_xg'],kind='bar',color=['green','red'])
plt.xlabel('Home Team')
plt.ylabel('Home Xg')
plt.title('Home Teams Estimated Goals')
plt.show()

# %%
df4=df.groupby('home_team')

# %%
(df4)

# %%
df4=df.groupby("home_team")

# %%
df4

# %%
df.groupby('home_team')['home_score']. mean()
# Out:
# home_team
# Algeria         0.833333
# Angola          0.000000
# Argentina       2.050847
# Australia       1.000000
# Austria         2.000000
#                   ...
# Uruguay         2.060606
# Wales           0.666667
# West Germany    2.026316
# Yugoslavia      2.562500
# Zaire           0.000000
# Name: home_score, Length: 82, dtype: float64

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %%
dg=df.groupby('home_team')['home_xg']

# %%
print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
das=pd.DataFrame({'Branch':['CSE','ECE','MSC','BBA','BCA'],'Salary':[10000,15000,20000,15000,13000],'Name':['A','B','C','D','E']})

# %%
das
# Out:
#   Branch  Salary Name
# 0    CSE   10000    A
# 1    ECE   15000    B
# 2    MSC   20000    C
# 3    BBA   15000    D
# 4    BCA   13000    E

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %%
sv=das.groupby('Branch')['Salary']

# %%
sv.agg(['mean','min'])
# Out:
#            mean    min
# Branch
# BBA     15000.0  15000
# BCA     13000.0  13000
# CSE     10000.0  10000
# ECE     15000.0  15000
# MSC     20000.0  20000

# %%
sv2=das.groupby(['Branch','Name'])['Salary']

# %%
sv2.max()
# Out:
# Branch  Name
# BBA     D       15000
# BCA     E       13000
# CSE     A       10000
# ECE     B       15000
# MSC     C       20000
# Name: Salary, dtype: int64

# %%
df.shape
# Out:
# (964, 44)
